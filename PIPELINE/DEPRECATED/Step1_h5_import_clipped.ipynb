# %%
import os
import numpy as np
import h5py as h5
import matplotlib.pyplot as plt
import Step1_h5_import_clipped_v2 as image_import

directory = '/Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/XZ/240515 Animal/240515_2hr p.i. RO right side re'
experiment_title = '2hr p.i. RO right side re'
base_data_folder = "240817_processing_from_raw"


# Load bias and slope arrays for the darkcount model
directory1 = f'/Users/allisondennis/Spectral_demixing/notebooks/PIPELINE/data/'
bias_file = 'b.npy'
slope_file = 'Sd.npy'
saturation_file = 'Smax.npy'
smooth_file = 'smooth.npy'
Slinear_file = 'Slinear.npy'

b = np.load(os.path.join(directory1, bias_file))
Sd = np.load(os.path.join(directory1, slope_file))
Smax = np.load(os.path.join(directory1, saturation_file))
smoothness = np.load(os.path.join(directory1, smooth_file))
#Slinear = np.load(os.path.join(directory1, Slinear_file))
Slinear = Smax



# Step 1: Import and save raw data
image_import.import_and_save_raw(directory, experiment_title, base_data_folder)

# Step 2: Clip and save data
image_import.clip_and_save(directory, Slinear, base_data_folder)

# Step 3: Denoise and save data
image_import.denoise_and_save(directory, experiment_title, Sd, b, base_data_folder)

# Step 4: Clip, denoise, and save data
image_import.clip_denoise_and_save(directory, experiment_title, Sd, b, base_data_folder)

# Step 5: Calculate and save Smax_adjusted
image_import.calculate_Slinear_adjusted(directory, experiment_title, Sd, b, Slinear, base_data_folder)

# Generate import report
image_import.generate_import_report(directory, experiment_title, Sd, b, Slinear, base_data_folder)

print("Processing complete.")
# Out:
# Final shape of image array for 2hr p.i. RO right side re_670_BP1150: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_670_BP1200: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_670_BP1250: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_670_BP1300: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_670_BP1350: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_670_BP1575: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_760_BP1150: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_760_BP1200: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_760_BP1250: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_760_BP1300: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_760_BP1350: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_760_BP1575: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_808_BP1150: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_808_BP1200: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_808_BP1250: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_808_BP1300: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_808_BP1350: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Final shape of image array for 2hr p.i. RO right side re_808_BP1575: (4,), dtype: [('exposure_time', '<f8'), ('image', '<f8', (640, 512))]
# Raw data saved in: /Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/XZ/240515 Animal/240515_2hr p.i. RO right side re/240817_processing_from_raw/raw_data
# Clipped data saved in: /Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/XZ/240515 Animal/240515_2hr p.i. RO right side re/240817_processing_from_raw/processed_data
# Denoised data saved in: /Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/XZ/240515 Animal/240515_2hr p.i. RO right side re/240817_processing_from_raw/processed_data
# Clipped and denoised data saved in: /Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/XZ/240515 Animal/240515_2hr p.i. RO right side re/240817_processing_from_raw/final_data
# Slinear_adjusted saved in: /Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/XZ/240515 Animal/240515_2hr p.i. RO right side re/240817_processing_from_raw/final_data
# Import report saved: /Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/XZ/240515 Animal/240515_2hr p.i. RO right side re/240817_processing_from_raw/reports/import_report_2hr p.i. RO right side re_20240817_224006.pdf
# Processing complete.
