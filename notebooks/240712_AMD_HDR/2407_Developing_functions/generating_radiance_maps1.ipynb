# %% [markdown]
# Use the h5_import code to import the experimental data from the IR VIVO and save npy files containing the darkcount-subtracted pixel intensities (i.e., denoised images) and their respective exposure times.
#
# Next use these images to generate radiance maps and HDR images

# %%
import os
import numpy as np
import logging
from image_analysis import load_processed_data
from image_radiance1 import generate_multi_page_report, process_hdr_images

if __name__ == "__main__":
    # Set up logging
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    logger = logging.getLogger(__name__)

    # Specify the directory and experiment title
    directory = './data/240515_2hr p.i. RO right side re'
    experiment_title = '2hr p.i. RO right side re'

    # Load the processed data
    loaded_data = load_processed_data(directory, experiment_title)

    # Process HDR images and get all necessary data
    processed_data = process_hdr_images(directory, experiment_title, smoothing_lambda=1000)

    # Generate the multi-page report
    generate_multi_page_report(processed_data, directory, experiment_title)

    logger.info(f"Processed {len(processed_data)} files.")
# Out:
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_670_BP1350_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_760_BP1200_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_670_BP1575_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_760_BP1300_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_670_BP1250_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_808_BP1200_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_670_BP1150_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_808_BP1300_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_808_BP1575_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_808_BP1350_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_808_BP1250_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_760_BP1150_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_760_BP1350_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_670_BP1200_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_760_BP1575_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_670_BP1300_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_808_BP1150_denoised.npy
# Loaded denoised images for 2hr p.i. RO right side re from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_760_BP1250_denoised.npy
# Loaded exposure times from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_exposure_times.npy
# z_max: 2808; z_min: 0
# Number of valid samples: 11614
# 2024-07-29 22:05:08,833 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_670_BP1350__radiance_map.npy
# 2024-07-29 22:05:08,833 - INFO - Processed 2hr p.i. RO right side re_670_BP1350_denoised.npy
# z_max: 3169; z_min: 0
# Number of valid samples: 11145
# 2024-07-29 22:05:30,430 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_760_BP1200__radiance_map.npy
# 2024-07-29 22:05:30,430 - INFO - Processed 2hr p.i. RO right side re_760_BP1200_denoised.npy
# z_max: 1645; z_min: 0
# Number of valid samples: 2984
# 2024-07-29 22:05:35,843 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_670_BP1575__radiance_map.npy
# 2024-07-29 22:05:35,844 - INFO - Processed 2hr p.i. RO right side re_670_BP1575_denoised.npy
# z_max: 3312; z_min: 0
# Number of valid samples: 12245
# 2024-07-29 22:06:01,992 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_760_BP1300__radiance_map.npy
# 2024-07-29 22:06:01,992 - INFO - Processed 2hr p.i. RO right side re_760_BP1300_denoised.npy
# z_max: 3356; z_min: 0
# Number of valid samples: 12249
# 2024-07-29 22:06:35,084 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_670_BP1250__radiance_map.npy
# 2024-07-29 22:06:35,084 - INFO - Processed 2hr p.i. RO right side re_670_BP1250_denoised.npy
# z_max: 3046; z_min: 0
# Number of valid samples: 13088
# 2024-07-29 22:06:56,550 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_808_BP1200__radiance_map.npy
# 2024-07-29 22:06:56,551 - INFO - Processed 2hr p.i. RO right side re_808_BP1200_denoised.npy
# z_max: 3181; z_min: 0
# Number of valid samples: 10853
# 2024-07-29 22:07:17,755 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_670_BP1150__radiance_map.npy
# 2024-07-29 22:07:17,756 - INFO - Processed 2hr p.i. RO right side re_670_BP1150_denoised.npy
# z_max: 3171; z_min: 0
# Number of valid samples: 10850
# 2024-07-29 22:07:38,302 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_808_BP1300__radiance_map.npy
# 2024-07-29 22:07:38,302 - INFO - Processed 2hr p.i. RO right side re_808_BP1300_denoised.npy
# z_max: 1244; z_min: 0
# Number of valid samples: 3628
# 2024-07-29 22:07:42,124 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_808_BP1575__radiance_map.npy
# 2024-07-29 22:07:42,125 - INFO - Processed 2hr p.i. RO right side re_808_BP1575_denoised.npy
# z_max: 2553; z_min: 0
# Number of valid samples: 9690
# 2024-07-29 22:07:57,060 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_808_BP1350__radiance_map.npy
# 2024-07-29 22:07:57,061 - INFO - Processed 2hr p.i. RO right side re_808_BP1350_denoised.npy
# z_max: 3240; z_min: 0
# Number of valid samples: 11454
# 2024-07-29 22:08:21,925 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_808_BP1250__radiance_map.npy
# 2024-07-29 22:08:21,926 - INFO - Processed 2hr p.i. RO right side re_808_BP1250_denoised.npy
# z_max: 3174; z_min: 0
# Number of valid samples: 10730
# 2024-07-29 22:08:43,877 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_760_BP1150__radiance_map.npy
# 2024-07-29 22:08:43,877 - INFO - Processed 2hr p.i. RO right side re_760_BP1150_denoised.npy
# z_max: 2854; z_min: 0
# Number of valid samples: 11789
# 2024-07-29 22:09:06,915 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_760_BP1350__radiance_map.npy
# 2024-07-29 22:09:06,916 - INFO - Processed 2hr p.i. RO right side re_760_BP1350_denoised.npy
# z_max: 3153; z_min: 0
# Number of valid samples: 10909
# 2024-07-29 22:09:29,090 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_670_BP1200__radiance_map.npy
# 2024-07-29 22:09:29,091 - INFO - Processed 2hr p.i. RO right side re_670_BP1200_denoised.npy
# z_max: 1407; z_min: 0
# Number of valid samples: 3401
# 2024-07-29 22:09:33,371 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_760_BP1575__radiance_map.npy
# 2024-07-29 22:09:33,372 - INFO - Processed 2hr p.i. RO right side re_760_BP1575_denoised.npy
# z_max: 3256; z_min: 0
# Number of valid samples: 11832
# 2024-07-29 22:09:59,926 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_670_BP1300__radiance_map.npy
# 2024-07-29 22:09:59,927 - INFO - Processed 2hr p.i. RO right side re_670_BP1300_denoised.npy
# z_max: 3106; z_min: 0
# Number of valid samples: 12647
# 2024-07-29 22:10:29,543 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_808_BP1150__radiance_map.npy
# 2024-07-29 22:10:29,543 - INFO - Processed 2hr p.i. RO right side re_808_BP1150_denoised.npy
# z_max: 3361; z_min: 0
# Number of valid samples: 12627
# 2024-07-29 22:10:58,392 - INFO - Radiance map saved to: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_760_BP1250__radiance_map.npy
# 2024-07-29 22:10:58,392 - INFO - Processed 2hr p.i. RO right side re_760_BP1250_denoised.npy
# 2024-07-29 22:10:58,393 - INFO - Finished processing all files.
# /Users/allisondennis/Spectral_demixing/notebooks/2407_AMD_HDR/2407_Developing_functions/image_radiance1.py:328: RuntimeWarning: divide by zero encountered in log
#   plot_radiance_map(np.log(data['radiance_map']), ax=ax6)
# 2024-07-29 22:10:59,568 - INFO - Added report page for 2hr p.i. RO right side re_670_BP1350_denoised.npy
# 2024-07-29 22:11:00,601 - INFO - Added report page for 2hr p.i. RO right side re_760_BP1200_denoised.npy
# 2024-07-29 22:11:01,477 - INFO - Added report page for 2hr p.i. RO right side re_670_BP1575_denoised.npy
# 2024-07-29 22:11:02,485 - INFO - Added report page for 2hr p.i. RO right side re_760_BP1300_denoised.npy
# 2024-07-29 22:11:03,554 - INFO - Added report page for 2hr p.i. RO right side re_670_BP1250_denoised.npy
# 2024-07-29 22:11:04,564 - INFO - Added report page for 2hr p.i. RO right side re_808_BP1200_denoised.npy
# 2024-07-29 22:11:05,611 - INFO - Added report page for 2hr p.i. RO right side re_670_BP1150_denoised.npy
# 2024-07-29 22:11:06,602 - INFO - Added report page for 2hr p.i. RO right side re_808_BP1300_denoised.npy
# 2024-07-29 22:11:07,538 - INFO - Added report page for 2hr p.i. RO right side re_808_BP1575_denoised.npy
# 2024-07-29 22:11:08,627 - INFO - Added report page for 2hr p.i. RO right side re_808_BP1350_denoised.npy
# 2024-07-29 22:11:09,628 - INFO - Added report page for 2hr p.i. RO right side re_808_BP1250_denoised.npy
# 2024-07-29 22:11:10,694 - INFO - Added report page for 2hr p.i. RO right side re_760_BP1150_denoised.npy
# 2024-07-29 22:11:11,681 - INFO - Added report page for 2hr p.i. RO right side re_760_BP1350_denoised.npy
# 2024-07-29 22:11:12,732 - INFO - Added report page for 2hr p.i. RO right side re_670_BP1200_denoised.npy
# 2024-07-29 22:11:13,702 - INFO - Added report page for 2hr p.i. RO right side re_760_BP1575_denoised.npy
# 2024-07-29 22:11:14,698 - INFO - Added report page for 2hr p.i. RO right side re_670_BP1300_denoised.npy
# 2024-07-29 22:11:15,701 - INFO - Added report page for 2hr p.i. RO right side re_808_BP1150_denoised.npy
# 2024-07-29 22:11:16,718 - INFO - Added report page for 2hr p.i. RO right side re_760_BP1250_denoised.npy
# 2024-07-29 22:11:16,719 - INFO - Finished processing all files.
# 2024-07-29 22:11:24,836 - INFO - Report saved as data/240515_2hr p.i. RO right side re/hdr_report_2hr p.i. RO right side re_20240729_221058.pdf
# 2024-07-29 22:11:24,837 - INFO - Processed 18 files.
