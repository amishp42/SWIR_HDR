# %%
import numpy as np
import os


# data location
directory = f'./data/'
bias_file = 'b.npy'
slope_file = 'Sd.npy'

# Load bias and slope arrays
bias = np.load(os.path.join(directory, bias_file))
slope = np.load(os.path.join(directory, slope_file))



print(bias)
print(slope)
# Out:
# [[1146.85303289 1149.43108544 1158.04926923 ... 1150.72859893
#   1162.44011497 1155.64120502]
#  [1152.84964343 1150.4869709  1145.54093115 ... 1147.20016812
#   1150.64096098 1142.8608151 ]
#  [1146.01117167 1149.87581008 1156.02448548 ... 1158.74766127
#   1148.04634074 1149.36739066]
#  ...
#  [1147.43368855 1144.96314976 1145.68757287 ... 1144.3830093
#   1140.30231297 1149.28645028]
#  [1164.51793704 1148.89820765 1144.98568291 ... 1153.8875783
#   1148.10656471 1151.88993736]
#  [1161.44610754 1157.93671195 1153.25613493 ... 1151.69662952
#   1148.2023916  1147.36223867]]
# [[202.3842748  200.69034791 200.09982154 ... 198.1091118  184.54667164
#   196.41160922]
#  [191.89359679 196.86357732 203.78725914 ... 195.99462334 200.07532802
#   198.94266638]
#  [203.38606593 200.11972626 199.92824768 ... 188.2852417  195.71279882
#   199.41179783]
#  ...
#  [197.75231683 199.37538532 197.00833346 ... 197.16822671 199.60250168
#   193.05557915]
# ...
