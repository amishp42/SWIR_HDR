# %%
# Import the necessary modules
import darkcount_analysis as da
import matplotlib.pyplot as plt
# %matplotlib inline

# Set the directory paths
directory = '/Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/AP/240717_darkcountmeasure_lowgain_noaverage'
experiment_name = '240717_darkcountmeasure_lowgain_noaverage'
output_dir = './data'

# Import the darkcount data
darkcount_array, exposure_times = da.import_darkcount_data(directory)

# Analyze the darkcount data
analysis_results = da.analyze_darkcount_data(darkcount_array, exposure_times)

# Print summary statistics
print("Summary Statistics:")
for i, time in enumerate(exposure_times):
    print(f"Exposure Time: {time:.4g} s")
    print(f"  Mean: {analysis_results['mean'][i]:.2f}")
    print(f"  Std Dev: {analysis_results['std'][i]:.2f}")
    print(f"  Min: {analysis_results['min'][i]:.2f}")
    print(f"  Max: {analysis_results['max'][i]:.2f}")
    print(f"  Low Outliers: {analysis_results['low_outliers'][i]:.2f}%")
    print(f"  High Outliers: {analysis_results['high_outliers'][i]:.2f}%")
    print()

# Plot darkcount images
plt.figure(figsize=(20, 20))
da.plot_darkcount_images(darkcount_array, exposure_times)
plt.show()

# Plot mean darkcount vs exposure time
plt.figure(figsize=(10, 6))
da.plot_mean_darkcount(exposure_times, analysis_results['mean'])
plt.show()

# Generate the PDF report
da.generate_darkcount_report(darkcount_array, exposure_times, analysis_results, output_dir,experiment_name)
# Out:
# Shape of darkcount_array: (12, 640, 512)
# Shape of exposure_times: (12,)
# Summary Statistics:
# Exposure Time: 0.001 s
#   Mean: 1497.92
#   Std Dev: 2.99
#   Min: 1473.00
#   Max: 1511.00
#   Low Outliers: 1.58%
#   High Outliers: 3.00%
#
# Exposure Time: 0.002 s
#   Mean: 1493.14
#   Std Dev: 2.98
#   Min: 1479.00
#   Max: 1510.00
#   Low Outliers: 2.91%
#   High Outliers: 1.60%
#
# Exposure Time: 0.004 s
#   Mean: 1488.10
#   Std Dev: 3.00
#   Min: 1474.00
#   Max: 1504.00
#   Low Outliers: 3.03%
#   High Outliers: 1.58%
#
# Exposure Time: 0.008 s
#   Mean: 1484.02
#   Std Dev: 3.00
#   Min: 1470.00
#   Max: 1499.00
#   Low Outliers: 3.29%
#   High Outliers: 1.50%
#
# Exposure Time: 0.016 s
#   Mean: 1479.28
#   Std Dev: 3.03
#   Min: 1463.00
#   Max: 1494.00
#   Low Outliers: 2.81%
#   High Outliers: 1.99%
#
# Exposure Time: 0.032 s
#   Mean: 1475.61
#   Std Dev: 3.01
#   Min: 1461.00
#   Max: 1494.00
#   Low Outliers: 2.07%
#   High Outliers: 2.50%
#
# Exposure Time: 0.064 s
#   Mean: 1471.93
#   Std Dev: 3.00
#   Min: 1458.00
#   Max: 1487.00
#   Low Outliers: 1.58%
#   High Outliers: 3.17%
#
# Exposure Time: 0.128 s
#   Mean: 1468.18
#   Std Dev: 3.01
#   Min: 1451.00
#   Max: 1483.00
#   Low Outliers: 2.93%
#   High Outliers: 1.73%
#
# Exposure Time: 0.256 s
#   Mean: 1465.33
#   Std Dev: 3.01
#   Min: 1450.00
#   Max: 1482.00
#   Low Outliers: 2.57%
#   High Outliers: 1.98%
#
# Exposure Time: 0.512 s
#   Mean: 1463.77
#   Std Dev: 3.02
#   Min: 1446.00
#   Max: 1482.00
#   Low Outliers: 1.88%
#   High Outliers: 2.79%
#
# Exposure Time: 1.024 s
#   Mean: 1464.88
#   Std Dev: 3.05
#   Min: 1448.00
#   Max: 1478.00
#   Low Outliers: 1.80%
#   High Outliers: 3.15%
#
# Exposure Time: 2.048 s
#   Mean: 1470.96
#   Std Dev: 3.17
#   Min: 1456.00
#   Max: 1487.00
#   Low Outliers: 2.08%
#   High Outliers: 1.85%
# Report saved as ./data/240717_darkcountmeasure_lowgain_noaverage_darkcount_analysis_report.pdf
