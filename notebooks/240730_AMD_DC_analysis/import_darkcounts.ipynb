# %%
# Import the necessary modules
import darkcount_analysis as da
import matplotlib.pyplot as plt
# %matplotlib inline

# Set the directory paths
directory = '/Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/AP/AP240717_darkcountmeasure_lowgain'
output_dir = './data
experiment_name = 'AP240717_darkcountmeasure_lowgain'

# Import the darkcount data
darkcount_array, exposure_times = da.import_darkcount_data(directory)

# Analyze the darkcount data
analysis_results = da.analyze_darkcount_data(darkcount_array, exposure_times)

# Print summary statistics
print("Summary Statistics:")
for i, time in enumerate(exposure_times):
    print(f"Exposure Time: {time:.4g} s")
    print(f"  Mean: {analysis_results['mean'][i]:.2f}")
    print(f"  Std Dev: {analysis_results['std'][i]:.2f}")
    print(f"  Min: {analysis_results['min'][i]:.2f}")
    print(f"  Max: {analysis_results['max'][i]:.2f}")
    print(f"  Low Outliers: {analysis_results['low_outliers'][i]:.2f}%")
    print(f"  High Outliers: {analysis_results['high_outliers'][i]:.2f}%")
    print()

# Plot darkcount images
plt.figure(figsize=(20, 20))
da.plot_darkcount_images(darkcount_array, exposure_times)
plt.show()

# Plot mean darkcount vs exposure time
plt.figure(figsize=(10, 6))
da.plot_mean_darkcount(exposure_times, analysis_results['mean'])
plt.show()

# Generate the PDF report
da.generate_darkcount_report(darkcount_array, exposure_times, analysis_results, output_dir,experiment_name)
# Out:
# Shape of darkcount_array: (12, 640, 512)
# Shape of exposure_times: (12,)
# Summary Statistics:
# Exposure Time: 0.001 s
#   Mean: 1496.93
#   Std Dev: 1.04
#   Min: 1488.00
#   Max: 1503.00
#   Low Outliers: 0.76%
#   High Outliers: 0.56%
#
# Exposure Time: 0.002 s
#   Mean: 1492.86
#   Std Dev: 1.06
#   Min: 1485.00
#   Max: 1499.00
#   Low Outliers: 0.97%
#   High Outliers: 5.41%
#
# Exposure Time: 0.004 s
#   Mean: 1487.61
#   Std Dev: 1.03
#   Min: 1481.00
#   Max: 1493.00
#   Low Outliers: 1.63%
#   High Outliers: 2.93%
#
# Exposure Time: 0.008 s
#   Mean: 1483.16
#   Std Dev: 1.04
#   Min: 1476.00
#   Max: 1489.00
#   Low Outliers: 4.82%
#   High Outliers: 1.03%
#
# Exposure Time: 0.016 s
#   Mean: 1479.02
#   Std Dev: 1.05
#   Min: 1473.00
#   Max: 1484.00
#   Low Outliers: 0.67%
#   High Outliers: 0.78%
#
# Exposure Time: 0.032 s
#   Mean: 1475.30
#   Std Dev: 1.04
#   Min: 1469.00
#   Max: 1481.00
#   Low Outliers: 3.58%
#   High Outliers: 1.51%
#
# Exposure Time: 0.064 s
#   Mean: 1470.88
#   Std Dev: 1.02
#   Min: 1464.00
#   Max: 1477.00
#   Low Outliers: 0.70%
#   High Outliers: 5.05%
#
# Exposure Time: 0.128 s
#   Mean: 1467.16
#   Std Dev: 1.01
#   Min: 1461.00
#   Max: 1473.00
#   Low Outliers: 4.15%
#   High Outliers: 0.81%
#
# Exposure Time: 0.256 s
#   Mean: 1464.03
#   Std Dev: 0.98
#   Min: 1458.00
#   Max: 1469.00
#   Low Outliers: 5.07%
#   High Outliers: 5.92%
#
# Exposure Time: 0.512 s
#   Mean: 1462.10
#   Std Dev: 0.98
#   Min: 1455.00
#   Max: 1467.00
#   Low Outliers: 4.42%
#   High Outliers: 0.48%
#
# Exposure Time: 1.024 s
#   Mean: 1462.72
#   Std Dev: 0.97
#   Min: 1455.00
#   Max: 1469.00
#   Low Outliers: 0.89%
#   High Outliers: 2.73%
#
# Exposure Time: 2.048 s
#   Mean: 1468.22
#   Std Dev: 1.08
#   Min: 1458.00
#   Max: 1479.00
#   Low Outliers: 5.17%
#   High Outliers: 1.14%
# Report saved as ./data/AP240717_darkcountmeasure_lowgain/darkcount_analysis_report.pdf
