# %% [markdown]
# Version of darkcount import and analysis (used with darkcount_analysis1.py) that can use mixed sets of data (i.e., overlapping ranges of exposure times that were taken at different times, but aggregated into a single directory folder)
#
# -> Now uses a linear-to-asymptote fitting function and determines the linear range on the upper and lower bounds and outputs Smax; adds date and time stamp to PDF output

# %%
# Import the necessary modules
import darkcount_analysis2 as da
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image
Image.MAX_IMAGE_PIXELS = None  # Disable the DecompressionBomb warning

# Set the directory paths
directory = '/Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/darkcounts_combined'
experiment_name = 'darkcounts_combined'
output_dir = './data'

# Import the darkcount data
darkcount_array, exposure_times = da.import_darkcount_data(directory)

# Sort the data by exposure times
darkcount_array, exposure_times = da.sort_by_exposure_time(darkcount_array, exposure_times)

# Analyze the darkcount data
analysis_results = da.analyze_darkcount_data(darkcount_array, exposure_times)

# Fit curve and find linear range
popt = da.fit_s_curve(exposure_times, analysis_results['mean'])
linear_range = da.find_linear_range(exposure_times, analysis_results['mean'], popt)



print(f"Exposure times: {exposure_times}")
print(f"Mean values: {analysis_results['mean']}")
print(f"Fitted parameters (popt): {popt}")
print(f"Calculated linear range: {linear_range}")

# Generate the PDF report
da.generate_darkcount_report(darkcount_array, exposure_times, analysis_results, output_dir, experiment_name, popt, linear_range)

# Print fit results
slope, intercept, Smax, smoothness = popt
print(f"Slope of linear part: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"Smax: {Smax:.2f}")
print(f"Smoothness: {smoothness:.2f}")
print(f"Linear range: {linear_range[0]:.2f}s to {linear_range[1]:.2f}s")
# Out:
# Shape of darkcount_array: (42, 640, 512)
# Shape of exposure_times: (42,)
# Debug - linear_to_asymptote called with: t=(42,), slope=1111.9979619979858, intercept=1141.9905670166015, Smax=4397.898443603515, smoothness=0.1
# Debug - linear_to_asymptote called with: t=(42,), slope=1111.9979785680466, intercept=1141.9905670166015, Smax=4397.898443603515, smoothness=0.1
# Debug - linear_to_asymptote called with: t=(42,), slope=1111.9979619979858, intercept=1141.990584033587, Smax=4397.898443603515, smoothness=0.1
# Debug - linear_to_asymptote called with: t=(42,), slope=1111.9979619979858, intercept=1141.9905670166015, Smax=4397.898509137309, smoothness=0.1
# Debug - linear_to_asymptote called with: t=(42,), slope=1111.9979619979858, intercept=1141.9905670166015, Smax=4397.898443603515, smoothness=0.1000000149011612
# Debug - linear_to_asymptote called with: t=(42,), slope=698.9631748040315, intercept=717.8154813197762, Smax=4214.5074141768855, smoothness=0.017157012915389416
# Debug - linear_to_asymptote called with: t=(42,), slope=698.9631852193944, intercept=717.8154813197762, Smax=4214.5074141768855, smoothness=0.017157012915389416
# Debug - linear_to_asymptote called with: t=(42,), slope=698.9631748040315, intercept=717.8154920160604, Smax=4214.5074141768855, smoothness=0.017157012915389416
# Debug - linear_to_asymptote called with: t=(42,), slope=698.9631748040315, intercept=717.8154813197762, Smax=4214.507476977939, smoothness=0.017157012915389416
# Debug - linear_to_asymptote called with: t=(42,), slope=698.9631748040315, intercept=717.8154813197762, Smax=4214.5074141768855, smoothness=0.01715702781655061
# Debug - linear_to_asymptote called with: t=(42,), slope=482.9678325692165, intercept=514.8809199609054, Smax=4198.8402104927845, smoothness=0.011958063221010676
# Debug - linear_to_asymptote called with: t=(42,), slope=482.96783976599806, intercept=514.8809199609054, Smax=4198.8402104927845, smoothness=0.011958063221010676
# Debug - linear_to_asymptote called with: t=(42,), slope=482.9678325692165, intercept=514.880927633229, Smax=4198.8402104927845, smoothness=0.011958063221010676
# Debug - linear_to_asymptote called with: t=(42,), slope=482.9678325692165, intercept=514.8809199609054, Smax=4198.840273060379, smoothness=0.011958063221010676
# Debug - linear_to_asymptote called with: t=(42,), slope=482.9678325692165, intercept=514.8809199609054, Smax=4198.8402104927845, smoothness=0.01195807812217187
# Debug - linear_to_asymptote called with: t=(42,), slope=374.15948028710477, intercept=562.1817751445535, Smax=4184.304743173771, smoothness=0.01180610365862045
# Debug - linear_to_asymptote called with: t=(42,), slope=374.1594858625155, intercept=562.1817751445535, Smax=4184.304743173771, smoothness=0.01180610365862045
# Debug - linear_to_asymptote called with: t=(42,), slope=374.15948028710477, intercept=562.1817835217148, Smax=4184.304743173771, smoothness=0.01180610365862045
# Debug - linear_to_asymptote called with: t=(42,), slope=374.15948028710477, intercept=562.1817751445535, Smax=4184.304805524771, smoothness=0.01180610365862045
# Debug - linear_to_asymptote called with: t=(42,), slope=374.15948028710477, intercept=562.1817751445535, Smax=4184.304743173771, smoothness=0.011806118559781644
# Debug - linear_to_asymptote called with: t=(42,), slope=294.4210015092416, intercept=732.6608524421547, Smax=4181.213810195635, smoothness=0.011894444776463316
# Debug - linear_to_asymptote called with: t=(42,), slope=294.4210058964564, intercept=732.6608524421547, Smax=4181.213810195635, smoothness=0.011894444776463316
# Debug - linear_to_asymptote called with: t=(42,), slope=294.4210015092416, intercept=732.6608633596521, Smax=4181.213810195635, smoothness=0.011894444776463316
# Debug - linear_to_asymptote called with: t=(42,), slope=294.4210015092416, intercept=732.6608524421547, Smax=4181.213872500576, smoothness=0.011894444776463316
# Debug - linear_to_asymptote called with: t=(42,), slope=294.4210015092416, intercept=732.6608524421547, Smax=4181.213810195635, smoothness=0.01189445967762451
# Debug - linear_to_asymptote called with: t=(42,), slope=224.68547659491452, intercept=1048.704491286934, Smax=4191.14673422189, smoothness=0.011829038690265055
# Debug - linear_to_asymptote called with: t=(42,), slope=224.68547994298902, intercept=1048.704491286934, Smax=4191.14673422189, smoothness=0.011829038690265055
# Debug - linear_to_asymptote called with: t=(42,), slope=224.68547659491452, intercept=1048.7045069138487, Smax=4191.14673422189, smoothness=0.011829038690265055
# Debug - linear_to_asymptote called with: t=(42,), slope=224.68547659491452, intercept=1048.704491286934, Smax=4191.146796674843, smoothness=0.011829038690265055
# Debug - linear_to_asymptote called with: t=(42,), slope=224.68547659491452, intercept=1048.704491286934, Smax=4191.14673422189, smoothness=0.011829053591426249
# Debug - linear_to_asymptote called with: t=(42,), slope=199.49705224593953, intercept=1173.7843119057252, Smax=4195.407994974764, smoothness=0.011552249931054318
# Debug - linear_to_asymptote called with: t=(42,), slope=199.49705521867727, intercept=1173.7843119057252, Smax=4195.407994974764, smoothness=0.011552249931054318
# Debug - linear_to_asymptote called with: t=(42,), slope=199.49705224593953, intercept=1173.7843293964745, Smax=4195.407994974764, smoothness=0.011552249931054318
# Debug - linear_to_asymptote called with: t=(42,), slope=199.49705224593953, intercept=1173.7843119057252, Smax=4195.408057491215, smoothness=0.011552249931054318
# Debug - linear_to_asymptote called with: t=(42,), slope=199.49705224593953, intercept=1173.7843119057252, Smax=4195.407994974764, smoothness=0.011552264832215511
# Debug - linear_to_asymptote called with: t=(42,), slope=199.42216725107363, intercept=1174.4557595935428, Smax=4254.935999225793, smoothness=0.011190540844319277
# Debug - linear_to_asymptote called with: t=(42,), slope=199.42217022269548, intercept=1174.4557595935428, Smax=4254.935999225793, smoothness=0.011190540844319277
# Debug - linear_to_asymptote called with: t=(42,), slope=199.42216725107363, intercept=1174.4557770942974, Smax=4254.935999225793, smoothness=0.011190540844319277
# Debug - linear_to_asymptote called with: t=(42,), slope=199.42216725107363, intercept=1174.4557595935428, Smax=4254.93606262928, smoothness=0.011190540844319277
# Debug - linear_to_asymptote called with: t=(42,), slope=199.42216725107363, intercept=1174.4557595935428, Smax=4254.935999225793, smoothness=0.01119055574548047
# Debug - linear_to_asymptote called with: t=(42,), slope=200.18958466035727, intercept=1169.397025189782, Smax=4296.005824416965, smoothness=0.0010513452140327693
# Debug - linear_to_asymptote called with: t=(42,), slope=200.2860876158007, intercept=1169.2456011072206, Smax=4265.201961999882, smoothness=0.003043247812596843
# Debug - linear_to_asymptote called with: t=(42,), slope=200.30873544760905, intercept=1169.215509798581, Smax=4257.496540985307, smoothness=0.0035424869480056827
# Debug - linear_to_asymptote called with: t=(42,), slope=200.3087384324418, intercept=1169.215509798581, Smax=4257.496540985307, smoothness=0.0035424869480056827
# Debug - linear_to_asymptote called with: t=(42,), slope=200.30873544760905, intercept=1169.2155272212499, Smax=4257.496540985307, smoothness=0.0035424869480056827
# Debug - linear_to_asymptote called with: t=(42,), slope=200.30873544760905, intercept=1169.215509798581, Smax=4257.496604426949, smoothness=0.0035424869480056827
# Debug - linear_to_asymptote called with: t=(42,), slope=200.30873544760905, intercept=1169.215509798581, Smax=4257.496540985307, smoothness=0.0035425018491668766
# Debug - linear_to_asymptote called with: t=(42,), slope=200.55294455161732, intercept=1169.090466189198, Smax=4260.048726250817, smoothness=0.004505557811390696
# Debug - linear_to_asymptote called with: t=(42,), slope=200.55294754008906, intercept=1169.090466189198, Smax=4260.048726250817, smoothness=0.004505557811390696
# Debug - linear_to_asymptote called with: t=(42,), slope=200.55294455161732, intercept=1169.0904836100035, Smax=4260.048726250817, smoothness=0.004505557811390696
# Debug - linear_to_asymptote called with: t=(42,), slope=200.55294455161732, intercept=1169.090466189198, Smax=4260.048789730489, smoothness=0.004505557811390696
# Debug - linear_to_asymptote called with: t=(42,), slope=200.55294455161732, intercept=1169.090466189198, Smax=4260.048726250817, smoothness=0.00450557271255189
# Debug - linear_to_asymptote called with: t=(42,), slope=201.0627476782934, intercept=1168.6472804311095, Smax=4265.1378697943055, smoothness=0.004633195606797587
# Debug - linear_to_asymptote called with: t=(42,), slope=201.0627506743618, intercept=1168.6472804311095, Smax=4265.1378697943055, smoothness=0.004633195606797587
# Debug - linear_to_asymptote called with: t=(42,), slope=201.0627476782934, intercept=1168.647297845311, Smax=4265.1378697943055, smoothness=0.004633195606797587
# Debug - linear_to_asymptote called with: t=(42,), slope=201.0627476782934, intercept=1168.6472804311095, Smax=4265.137933349813, smoothness=0.004633195606797587
# Debug - linear_to_asymptote called with: t=(42,), slope=201.0627476782934, intercept=1168.6472804311095, Smax=4265.1378697943055, smoothness=0.0046332105079587805
# Debug - linear_to_asymptote called with: t=(42,), slope=201.37672535667272, intercept=1167.731649206279, Smax=4275.4005926309765, smoothness=0.004330288823384863
# Debug - linear_to_asymptote called with: t=(42,), slope=201.37672835741978, intercept=1167.731649206279, Smax=4275.4005926309765, smoothness=0.004330288823384863
# Debug - linear_to_asymptote called with: t=(42,), slope=201.37672535667272, intercept=1167.7316666068364, Smax=4275.4005926309765, smoothness=0.004330288823384863
# Debug - linear_to_asymptote called with: t=(42,), slope=201.37672535667272, intercept=1167.731649206279, Smax=4275.40065633941, smoothness=0.004330288823384863
# Debug - linear_to_asymptote called with: t=(42,), slope=201.37672535667272, intercept=1167.731649206279, Smax=4275.4005926309765, smoothness=0.004330303724546057
# Debug - linear_to_asymptote called with: t=(42,), slope=201.57064116829545, intercept=1167.4843100276566, Smax=4295.935705937065, smoothness=0.003911705842568209
# Debug - linear_to_asymptote called with: t=(42,), slope=201.57064417193206, intercept=1167.4843100276566, Smax=4295.935705937065, smoothness=0.003911705842568209
# Debug - linear_to_asymptote called with: t=(42,), slope=201.57064116829545, intercept=1167.4843274245286, Smax=4295.935705937065, smoothness=0.003911705842568209
# Debug - linear_to_asymptote called with: t=(42,), slope=201.57064116829545, intercept=1167.4843100276566, Smax=4295.935769951496, smoothness=0.003911705842568209
# Debug - linear_to_asymptote called with: t=(42,), slope=201.57064116829545, intercept=1167.4843100276566, Smax=4295.935705937065, smoothness=0.003911720743729403
# Debug - linear_to_asymptote called with: t=(42,), slope=202.00321829825356, intercept=1166.9741233227728, Smax=4337.002763923774, smoothness=0.003232483846412606
# Debug - linear_to_asymptote called with: t=(42,), slope=202.00322130833607, intercept=1166.9741233227728, Smax=4337.002763923774, smoothness=0.003232483846412606
# Debug - linear_to_asymptote called with: t=(42,), slope=202.00321829825356, intercept=1166.9741407120423, Smax=4337.002763923774, smoothness=0.003232483846412606
# Debug - linear_to_asymptote called with: t=(42,), slope=202.00321829825356, intercept=1166.9741233227728, Smax=4337.002828550151, smoothness=0.003232483846412606
# Debug - linear_to_asymptote called with: t=(42,), slope=202.00321829825356, intercept=1166.9741233227728, Smax=4337.002763923774, smoothness=0.0032324987475738
# Debug - linear_to_asymptote called with: t=(42,), slope=201.98504622100367, intercept=1167.0758095001752, Smax=4344.993303767782, smoothness=0.0032329186312119594
# Debug - linear_to_asymptote called with: t=(42,), slope=201.9850492308154, intercept=1167.0758095001752, Smax=4344.993303767782, smoothness=0.0032329186312119594
# Debug - linear_to_asymptote called with: t=(42,), slope=201.98504622100367, intercept=1167.07582689096, Smax=4344.993303767782, smoothness=0.0032329186312119594
# Debug - linear_to_asymptote called with: t=(42,), slope=201.98504622100367, intercept=1167.0758095001752, Smax=4344.993368513227, smoothness=0.0032329186312119594
# Debug - linear_to_asymptote called with: t=(42,), slope=201.98504622100367, intercept=1167.0758095001752, Smax=4344.993303767782, smoothness=0.0032329335323731533
# Debug - linear_to_asymptote called with: t=(42,), slope=202.02779865365522, intercept=1167.0219908717181, Smax=4345.383594990046, smoothness=0.003215971264318559
# Debug - linear_to_asymptote called with: t=(42,), slope=202.02780166410403, intercept=1167.0219908717181, Smax=4345.383594990046, smoothness=0.003215971264318559
# Debug - linear_to_asymptote called with: t=(42,), slope=202.02779865365522, intercept=1167.0220082617009, Smax=4345.383594990046, smoothness=0.003215971264318559
# Debug - linear_to_asymptote called with: t=(42,), slope=202.02779865365522, intercept=1167.0219908717181, Smax=4345.383659741307, smoothness=0.003215971264318559
# Debug - linear_to_asymptote called with: t=(42,), slope=202.02779865365522, intercept=1167.0219908717181, Smax=4345.383594990046, smoothness=0.003215986165479753
# Debug - linear_to_asymptote called with: t=(42,), slope=202.0197752573542, intercept=1167.033804932877, Smax=4345.441196553385, smoothness=0.0032165634439731455
# Debug - linear_to_asymptote called with: t=(42,), slope=202.01977826768345, intercept=1167.033804932877, Smax=4345.441196553385, smoothness=0.0032165634439731455
# Debug - linear_to_asymptote called with: t=(42,), slope=202.0197752573542, intercept=1167.0338223230358, Smax=4345.441196553385, smoothness=0.0032165634439731455
# Debug - linear_to_asymptote called with: t=(42,), slope=202.0197752573542, intercept=1167.033804932877, Smax=4345.441261305506, smoothness=0.0032165634439731455
# Debug - linear_to_asymptote called with: t=(42,), slope=202.0197752573542, intercept=1167.033804932877, Smax=4345.441196553385, smoothness=0.0032165783451343394
# Debug - linear_to_asymptote called with: t=(42,), slope=202.0208850868516, intercept=1167.032362900988, Smax=4345.447500009466, smoothness=0.003216200058136207
# Debug - linear_to_asymptote called with: t=(42,), slope=202.02088809719737, intercept=1167.032362900988, Smax=4345.447500009466, smoothness=0.003216200058136207
# Debug - linear_to_asymptote called with: t=(42,), slope=202.0208850868516, intercept=1167.0323802911253, Smax=4345.447500009466, smoothness=0.003216200058136207
# Debug - linear_to_asymptote called with: t=(42,), slope=202.0208850868516, intercept=1167.032362900988, Smax=4345.44756476168, smoothness=0.003216200058136207
# Debug - linear_to_asymptote called with: t=(42,), slope=202.0208850868516, intercept=1167.032362900988, Smax=4345.447500009466, smoothness=0.003216214959297401
# Debug - linear_to_asymptote called with: t=(42,), slope=202.02068190866007, intercept=1167.0326542963064, Smax=4345.448451979358, smoothness=0.0032162227256972114
# Debug - linear_to_asymptote called with: t=(42,), slope=202.0206849190028, intercept=1167.0326542963064, Smax=4345.448451979358, smoothness=0.0032162227256972114
# Debug - linear_to_asymptote called with: t=(42,), slope=202.02068190866007, intercept=1167.032671686448, Smax=4345.448451979358, smoothness=0.0032162227256972114
# Debug - linear_to_asymptote called with: t=(42,), slope=202.02068190866007, intercept=1167.0326542963064, Smax=4345.448516731585, smoothness=0.0032162227256972114
# Debug - linear_to_asymptote called with: t=(42,), slope=202.02068190866007, intercept=1167.0326542963064, Smax=4345.448451979358, smoothness=0.0032162376268584053
# Debug - linear_to_asymptote called with: t=(42,), slope=202.02068190866007, intercept=1167.0326542963064, Smax=4345.448451979358, smoothness=0.0032162227256972114
# Exposure times: [6.4000000e-03 8.0000000e-03 1.2800000e-02 1.6000000e-02 2.5600000e-02
#  3.2000000e-02 5.1200000e-02 6.4000000e-02 1.0240000e-01 1.2800000e-01
#  2.0480000e-01 2.5000000e-01 2.5600000e-01 4.0960000e-01 5.0000000e-01
#  5.1200000e-01 8.1920000e-01 1.0000000e+00 1.0000000e+00 1.0000000e+00
#  1.0240000e+00 1.3000000e+00 1.6384000e+00 1.6900000e+00 2.0000000e+00
#  2.0000000e+00 2.0480000e+00 2.1970000e+00 2.8561000e+00 3.7129300e+00
#  4.0000000e+00 4.0000000e+00 4.8268090e+00 6.2748510e+00 8.0000000e+00
#  8.1573070e+00 1.0604499e+01 1.3785849e+01 1.6000000e+01 1.7921603e+01
#  2.3298085e+01 3.2000000e+01]
# Mean values: [1141.99056702 1142.11508484 1156.17873535 1156.46362915 1169.68284607
#  1170.45771484 1182.96641541 1184.82290649 1197.45141296 1203.16013489
#  1217.71993713 1228.54240112 1230.6291687  1250.44925537 1271.19384155
#  1280.28915405 1313.50240173 1412.33808899 1414.71095581 1354.66762695
#  1376.8275238  1471.91881714 1440.26758423 1544.98096313 1522.67546082
#  1600.58904419 1566.75384521 1641.27661438 1767.09264832 1931.39583435
#  1974.8190033  1870.11873779 2144.24761658 2426.06947632 2745.25769348
#  2800.58114319 3312.10494995 3948.98703003 4137.4109375  4226.51104431
#  4325.79605408 4397.8984436 ]
# Fitted parameters (popt): [2.02020682e+02 1.16703265e+03 4.34544845e+03 3.21622273e-03]
# Calculated linear range: (0.0064, 13.785849)
# Debug - x_fine shape: (1000,)
# Debug - popt in plot_s_curve_fit: [2.02020682e+02 1.16703265e+03 4.34544845e+03 3.21622273e-03]
# Debug - type of popt: <class 'numpy.ndarray'>
# Debug - linear_range: (0.0064, 13.785849)
# Debug - linear_to_asymptote called with: t=(1000,), slope=202.02068190866007, intercept=1167.0326542963064, Smax=4345.448451979358, smoothness=0.0032162227256972114
# Debug - y_fine calculated successfully
# Report saved as ./data/darkcounts_combined_darkcount_analysis_report_20240806_115258.pdf
# Model parameters (Sd and b) saved in ./data
# Slope of linear part: 202.02
# Intercept: 1167.03
# Smax: 4345.45
# Smoothness: 0.00
# Linear range: 0.01s to 13.79s

# %%
print(exposure_times)
# Out:
# [6.4000000e-03 8.0000000e-03 1.2800000e-02 1.6000000e-02 2.5600000e-02
#  3.2000000e-02 5.1200000e-02 6.4000000e-02 1.0240000e-01 1.2800000e-01
#  2.0480000e-01 2.5000000e-01 2.5600000e-01 4.0960000e-01 5.0000000e-01
#  5.1200000e-01 8.1920000e-01 1.0000000e+00 1.0000000e+00 1.0000000e+00
#  1.0240000e+00 1.3000000e+00 1.6384000e+00 1.6900000e+00 2.0000000e+00
#  2.0000000e+00 2.0480000e+00 2.1970000e+00 2.8561000e+00 3.7129300e+00
#  4.0000000e+00 4.0000000e+00 4.8268090e+00 6.2748510e+00 8.0000000e+00
#  8.1573070e+00 1.0604499e+01 1.3785849e+01 1.6000000e+01 1.7921603e+01
#  2.3298085e+01 3.2000000e+01]

# %%
print(popt)
# Out:
# [2.02020682e+02 1.16703265e+03 4.34544845e+03 3.21622273e-03]

# %%
print(*popt)
# Out:
# 202.02068190866007 1167.0326542963064 4345.448451979358 0.0032162227256972114
