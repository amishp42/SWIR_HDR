# %%
import os
import matplotlib.pyplot as plt
os.chdir('C:\\Users\\apate\\OneDrive - Northeastern University\\Dennis Lab site\\AP\\Spectral_demixing\\notebooks\\PIPELINE')
import Step2_image_radiance_dev as images

#no_weight, linear_weight, broadhat_weight, debevec_weight, robertson_weight
Z_min = 0
Z_max = [4500, 3500, 2500, 1500]

for weighting_func in [images.no_weight, images.linear_weight, images.square_weight, images.broadhat_weight, images.debevec_weight, images.robertson_weight]:
     #make new figure
     fig = plt.figure()
     for i in Z_max: 
         images.plot_weighting_function(weighting_func, Z_min, i, ax=None)
# Out:
# Error in plot_weighting_function: x and y must have same first dimension, but have shapes (4501,) and (1,)
# Error in plot_weighting_function: x and y must have same first dimension, but have shapes (3501,) and (1,)
# Error in plot_weighting_function: x and y must have same first dimension, but have shapes (2501,) and (1,)
# Error in plot_weighting_function: x and y must have same first dimension, but have shapes (1501,) and (1,)
