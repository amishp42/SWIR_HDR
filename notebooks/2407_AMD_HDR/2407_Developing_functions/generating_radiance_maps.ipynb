# %% [markdown]
# Use the h5_import code to import the experimental data from the IR VIVO and save npy files containing the darkcount-subtracted pixel intensities (i.e., denoised images) and their respective exposure times.
#
# Next use these images to generate radiance maps and HDR images

# %%
import os
import numpy as np
import logging
from image_analysis import load_processed_data
from image_analysis1 import generate_multi_page_report

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Specify the directory and experiment title
directory = '/path/to/your/data/240515_2hr p.i. RO right side re/'  # Update this path
experiment_title = '2hr p.i. RO right side re'  # Update this if needed

# Load the processed data
loaded_data = load_processed_data(directory, experiment_title)

# Get the list of available denoised image files
data_folder = os.path.join('data', os.path.basename(os.path.normpath(directory)))
denoised_files = [f for f in os.listdir(data_folder) if f.endswith('_denoised.npy')]

# Load exposure times
exposure_times = loaded_data['exposure_times']

# Generate the multi-page report
output_file = f'hdr_report_{experiment_title}.pdf'
generate_multi_page_report(denoised_files, exposure_times, data_folder, experiment_title, output_file)

logger.info(f"Processed {len(denoised_files)} files.")
# Out:
# Loaded denoised images for BP1350 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_760_BP1350_denoised.npy
# Loaded denoised images for BP1575 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_760_BP1575_denoised.npy
# Loaded denoised images for BP1200 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_670_BP1200_denoised.npy
# Loaded denoised images for BP1300 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_670_BP1300_denoised.npy
# Loaded denoised images for BP1150 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_808_BP1150_denoised.npy
# Loaded denoised images for BP1250 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_760_BP1250_denoised.npy
# Loaded denoised images for BP1575 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_808_BP1575_denoised.npy
# Loaded denoised images for BP1350 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_808_BP1350_denoised.npy
# Loaded denoised images for BP1250 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_808_BP1250_denoised.npy
# Loaded denoised images for BP1150 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_760_BP1150_denoised.npy
# Loaded denoised images for BP1200 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_808_BP1200_denoised.npy
# Loaded denoised images for BP1150 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_670_BP1150_denoised.npy
# Loaded denoised images for BP1300 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_808_BP1300_denoised.npy
# Loaded denoised images for BP1350 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_670_BP1350_denoised.npy
# Loaded denoised images for BP1575 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_670_BP1575_denoised.npy
# Loaded denoised images for BP1200 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_760_BP1200_denoised.npy
# Loaded denoised images for BP1300 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_760_BP1300_denoised.npy
# Loaded denoised images for BP1250 from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_2hr p.i. RO right side re_670_BP1250_denoised.npy
# Loaded exposure times from: data/240515_2hr p.i. RO right side re/2hr p.i. RO right side re_exposure_times.npy
# z_max: 2854; z_min: 0
# Number of valid samples: 2450
# 2024-07-12 00:50:59,409 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_760_BP1350_denoised.npy
# z_max: 1407; z_min: 0
# Number of valid samples: 216
# 2024-07-12 00:51:02,694 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_760_BP1575_denoised.npy
# z_max: 3153; z_min: 0
# Number of valid samples: 2864
# 2024-07-12 00:51:21,803 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_670_BP1200_denoised.npy
# z_max: 3256; z_min: 0
# Number of valid samples: 2985
# 2024-07-12 00:51:37,511 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_670_BP1300_denoised.npy
# z_max: 3106; z_min: 0
# Number of valid samples: 2376
# 2024-07-12 00:51:51,664 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_808_BP1150_denoised.npy
# z_max: 3361; z_min: 0
# Number of valid samples: 3120
# 2024-07-12 00:52:08,213 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_760_BP1250_denoised.npy
# z_max: 1244; z_min: 0
# Number of valid samples: 174
# 2024-07-12 00:52:11,050 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_808_BP1575_denoised.npy
# z_max: 2553; z_min: 0
# Number of valid samples: 1928
# 2024-07-12 00:52:20,032 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_808_BP1350_denoised.npy
# z_max: 3240; z_min: 0
# Number of valid samples: 2988
# 2024-07-12 00:52:34,738 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_808_BP1250_denoised.npy
# z_max: 3174; z_min: 0
# Number of valid samples: 2754
# 2024-07-12 00:52:48,800 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_760_BP1150_denoised.npy
# z_max: 3046; z_min: 0
# Number of valid samples: 2734
# 2024-07-12 00:53:01,507 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_808_BP1200_denoised.npy
# z_max: 3181; z_min: 0
# Number of valid samples: 2768
# 2024-07-12 00:53:15,309 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_670_BP1150_denoised.npy
# z_max: 3171; z_min: 0
# Number of valid samples: 2912
# 2024-07-12 00:53:29,572 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_808_BP1300_denoised.npy
# z_max: 2808; z_min: 0
# Number of valid samples: 2393
# 2024-07-12 00:53:41,493 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_670_BP1350_denoised.npy
# z_max: 1645; z_min: 0
# Number of valid samples: 205
# 2024-07-12 00:53:45,312 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_670_BP1575_denoised.npy
# z_max: 3169; z_min: 0
# Number of valid samples: 2920
# 2024-07-12 00:53:59,035 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_760_BP1200_denoised.npy
# z_max: 3312; z_min: 0
# Number of valid samples: 3068
# 2024-07-12 00:54:15,770 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_760_BP1300_denoised.npy
# z_max: 3356; z_min: 0
# Number of valid samples: 3032
# 2024-07-12 00:54:39,716 - INFO - Processed 2hr p.i. RO right side re_2hr p.i. RO right side re_670_BP1250_denoised.npy
# 2024-07-12 00:54:39,716 - INFO - Finished processing all files.
# 2024-07-12 00:54:42,963 - INFO - Report saved as data/240515_2hr p.i. RO right side re/hdr_report_2hr p.i. RO right side re_20240712_005046.pdf
# 2024-07-12 00:54:42,964 - INFO - Processed 18 files.
