# %% [markdown]
# Step0-- analyze and store info about the camera pixel-by-pixel DC model, saturation point)
# Step1-- import raw data from h5 files, clip the saturated pixels, subtract the DC noise, save data as additional npy arrays
# Step2-- *** Use the data to generate camera response functions and convert the multiple exposure times into a radiance map.**

# %%
import os
import numpy as np
import logging

 # process_and_save.py

from Step2_image_radiance_maps_from_raw import process_hdr_images, save_crf_data

# Your existing setup code here
directory = '/Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/AMD/240329_Water_immersed/'
experiment_title = 'Water_immersed'
base_data_folder = '240817_data_95xSmax'

# Add a parameter for the number of image sets to process
num_sets_to_process = 1  # Change this value to process more or fewer sets

# Process HDR images
processed_data = process_hdr_images(directory, experiment_title, base_data_folder, smoothing_lambda=1000, num_sets=num_sets_to_process)

# Save CRF data
crf_file = save_crf_data(processed_data, directory, experiment_title, base_data_folder)

print(f"CRF data saved to: {crf_file}")
# Out:
# Processing Water_immersed_808_BP1350
# Images shape: (15, 640, 512)
# Exposure times shape: (15,)
# Slinear shape: (640, 512)
# Sd shape: (640, 512)
# bias shape: (640, 512)
# Zmax_precomputed shape: (15, 640, 512)
# Zmin_precomputed shape: (15, 640, 512)
# Number of processed data items: 1
#
# Processing data item 1:
#   key: Water_immersed_808_BP1350
#   radiance_map shape: (640, 512)
#   response_curve shape: (4514,)
#   z_min: 717
#   z_max: 5230
#   intensity_samples shape: (20403, 15)
#   log_exposures shape: (20403, 15)
#   Zmin_sample: 1175.0
#   Zmax_sample: 3230.0
#
# Saving CRF data...
# CRF data saved to: /Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/AMD/240329_Water_immersed/240817_data_95xSmax/final_data/Water_immersed_crf_data.npz
# Verified saved data. Keys in the file:
#   key_0
#   radiance_map_0
#   response_curve_0
#   z_min_0
#   z_max_0
#   intensity_samples_0
#   log_exposures_0
#   Zmin_sample_0
#   Zmax_sample_0
# CRF data saved to: /Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/AMD/240329_Water_immersed/240817_data_95xSmax/final_data/Water_immersed_crf_data.npz

# %%
# generate_report.py

import os
import numpy as np
import logging
from Step2_image_radiance_maps_from_raw import load_crf_data, generate_multi_page_report, adaptive_weight

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Your existing setup code here
directory = '/Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/XZ/240515 Animal/240515_2hr p.i. RO right side re'
experiment_title = '2hr p.i. RO right side re'
base_data_folder = "240817_processing_from_raw"

# Load the saved CRF data
crf_file = os.path.join(directory, base_data_folder, "final_data", f"{experiment_title}_crf_data.npz")
processed_data = load_crf_data(crf_file)

# Generate the multi-page report
generate_multi_page_report(processed_data, directory, experiment_title, adaptive_weight, base_data_folder)

logger.info("Script execution complete")
# Out:
# Loading CRF data from: /Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/XZ/240515 Animal/240515_2hr p.i. RO right side re/240817_processing_from_raw/final_data/2hr p.i. RO right side re_crf_data.npz
# Keys in the loaded file:
#   key_0
#   radiance_map_0
#   response_curve_0
#   z_min_0
#   z_max_0
#   intensity_samples_0
#   log_exposures_0
#   Zmin_sample_0
#   Zmax_sample_0
# Processing data item 0
#   Loaded key_0: ndarray with shape (), dtype: <U36
#   Loaded radiance_map_0: ndarray with shape (640, 512), dtype: float32
#   Loaded response_curve_0: ndarray with shape (3747,), dtype: float64
#   Loaded z_min_0: ndarray with shape (), dtype: int64
#   Loaded z_max_0: ndarray with shape (), dtype: int64
#   Loaded intensity_samples_0: ndarray with shape (28720, 4), dtype: float32
#   Loaded log_exposures_0: ndarray with shape (28720, 4), dtype: float64
# Loaded 1 processed data items
# Error in Pixel-specific Weighting Function: 'Zmin_sample'
# Data shapes: key: (), radiance_map: (640, 512), response_curve: (3747,), z_min: (), z_max: (), intensity_samples: (28720, 4), log_exposures: (28720, 4)
# /Users/allisondennis/Spectral_demixing/notebooks/PIPELINE/Step2_image_radiance_maps_from_raw.py:469: RuntimeWarning: divide by zero encountered in log
#   log_radiance = np.log(radiance_map)
# /Users/allisondennis/Spectral_demixing/notebooks/PIPELINE/Step2_image_radiance_maps_from_raw.py:469: RuntimeWarning: invalid value encountered in log
#   log_radiance = np.log(radiance_map)
# INFO:Step2_image_radiance_maps_from_raw:Added report page for 2hr p.i. RO right side re_670_BP1250
# INFO:Step2_image_radiance_maps_from_raw:Finished processing all files.
# INFO:Step2_image_radiance_maps_from_raw:Report saved as /Users/allisondennis/Library/CloudStorage/OneDrive-NortheasternUniversity/Shared Documents - Dennis Lab/Image processing/IR VIVO data/XZ/240515 Animal/240515_2hr p.i. RO right side re/240817_processing_from_raw/reports/hdr_report_2hr p.i. RO right side re_20240818_125754.pdf
# INFO:__main__:Script execution complete
