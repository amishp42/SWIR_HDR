# %%
import simulatedata as sd

import numpy as np
import matplotlib.pyplot as plt
import tifffile
import os

# %%
exposure_times = [0.01, 0.05, 0.1, 0.5, 1, 5,10]
well_data,pixel_values = sd.generateWellData(exposure_times)

# %%
#save data as tif and .npy

#change directory to desired output

os.chdir("C:\\Users\\apate\\OneDrive - Northeastern University\\Dennis Lab site\\Image processing\\Simulated images\\240826")


for i in range(len(exposure_times)):
    tifffile.imsave(f"well_data_{exposure_times[i]}.tif", well_data[i])
    np.save(f"well_data_{exposure_times[i]}.npy", well_data[i])

np.save("well_data.npy", well_data)
np.save("well_values.npy", pixel_values)
# Out:
# C:\Users\apate\AppData\Local\Temp\ipykernel_28572\2588521931.py:9: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tifffile.imsave(f"well_data_{exposure_times[i]}.tif", well_data[i])

# %%
sd.save_h5("well_data.npy", exposure_times)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Saved 7 images as .h5 files in the 'output_h5_files' directory.
